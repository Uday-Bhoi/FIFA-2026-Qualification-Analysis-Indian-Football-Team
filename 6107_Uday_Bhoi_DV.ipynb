# %% [markdown]
# <a href="https://colab.research.google.com/github/Uday-Bhoi/CA-II/blob/main/6107_Uday_Bhoi_DV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Indian Football Team Analysis***
#
# ---

# %%
#first of all lets import all the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#loading the data
df_data=pd.read_csv('/content/AFC RANKING.csv')
#head is used to display first 5 records of the dataset
df_data.head()
# Out:
#    rank  country_full country_abrv  total_points  previous_points  \
# 0   135   Philippines          PHI       1095.66          1095.66
# 1   136      Malaysia          MAS       1091.57          1091.57
# 2   137        Kuwait          KUW       1090.42          1084.34
# 3   138  Turkmenistan          TKM       1089.77          1089.77
# 4    99         India          IND       1208.69          1204.90
#
#    rank_change confederation  rank_date
# 0            0           AFC  7/20/2023
# 1           -1           AFC  7/20/2023
# 2           -4           AFC  7/20/2023
# 3            0           AFC  7/20/2023
# 4           -1           AFC  7/20/2023

# %%
#head is used to display last 5 records of the dataset
df_data.tail()
# Out:
#     rank  country_full country_abrv  total_points  previous_points  \
# 43    54  Saudi Arabia          KSA       1421.46          1421.46
# 44    70          Iraq          IRQ       1345.21          1345.21
# 45    59         Qatar          QAT       1395.57          1393.52
# 46   146     Hong Kong          HKG       1062.39          1062.39
# 47    77       Lebanon          LIB       1308.00          1304.00
#
#     rank_change confederation   rank_date
# 43            1           AFC   7/20/2023
# 44            0           AFC   7/20/2023
# 45            1           AFC   7/20/2023
# 46            1           AFC  12/22/2022
# 47           -2           AFC   9/20/2018

# %%
#returns the number of columns and rows
df_data.shape
# Out:
# (48, 8)

# %%
#used to check whether null values are there in the dataset or not
null_values=df_data.isnull().sum()
print("Null values in the DataFrame:")
print(null_values)
#as there are no null Values our data is complete so we can do the further visualization
# Out:
# Null values in the DataFrame:
# rank               0
# country_full       0
# country_abrv       0
# total_points       0
# previous_points    0
# rank_change        0
# confederation      0
# rank_date          0
# dtype: int64

# %%
#info is used to get the datatype of each column with their name non-null count respectively
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             48 non-null     int64
#  1   country_full     48 non-null     object
#  2   country_abrv     48 non-null     object
#  3   total_points     48 non-null     float64
#  4   previous_points  48 non-null     float64
#  5   rank_change      48 non-null     int64
#  6   confederation    48 non-null     object
#  7   rank_date        48 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.1+ KB

# %%
#describe gives the Statistical Measures of the Data set such as Mean, max, min, count
df_data.describe()
# Out:
#              rank  total_points  previous_points  rank_change
# count   48.000000     48.000000        48.000000    48.000000
# mean   123.750000   1140.616875      1140.438958    -0.354167
# std     53.053766    207.429902       207.034003     1.175813
# min     20.000000    825.250000       825.250000    -4.000000
# 25%     81.500000    989.707500       990.035000     0.000000
# 50%    135.500000   1093.615000      1093.615000     0.000000
# 75%    163.750000   1298.390000      1298.195000     0.000000
# max    204.000000   1595.960000      1595.960000     1.000000

# %%
#returns the names of the colums
df_data.columns
# Out:
# Index(['rank', 'country_full', 'country_abrv', 'total_points',
#        'previous_points', 'rank_change', 'confederation', 'rank_date'],
#       dtype='object')

# %%
#it is used to return the number of duplicat values in the dataset
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.nunique()
# Out:
# rank               48
# country_full       47
# country_abrv       47
# total_points       48
# previous_points    48
# rank_change         6
# confederation       1
# rank_date           3
# dtype: int64

# %%
#here we got to know that all countries are there which are under AFC Confederation
df_data['country_full'].value_counts()
# Out:
# Lebanon                 2
# Philippines             1
# Pakistan                1
# Kyrgyz Republic         1
# Palestine               1
# Vietnam                 1
# IR Iran                 1
# Australia               1
# Korea Republic          1
# Japan                   1
# Sri Lanka               1
# Guam                    1
# Oman                    1
# Singapore               1
# Uzbekistan              1
# China PR                1
# Jordan                  1
# United Arab Emirates    1
# Bahrain                 1
# Syria                   1
# Saudi Arabia            1
# Iraq                    1
# Qatar                   1
# Myanmar                 1
# Afghanistan             1
# Malaysia                1
# Yemen                   1
# Kuwait                  1
# Turkmenistan            1
# India                   1
# Thailand                1
# Korea DPR               1
# Tajikistan              1
# Hong Kong, China        1
# Cambodia                1
# ...

# %% [markdown]
# # ***ROUND 2 AFC Qualifier ***

# %%
df = df_data.sort_values('rank', ascending=True)

new_df_data=df.head(24)
new_df_data
# Out:
#     rank          country_full country_abrv  total_points  previous_points  \
# 32    20                 Japan          JPN       1595.96          1595.96
# 29    22               IR Iran          IRN       1556.59          1556.59
# 30    27             Australia          AUS       1530.45          1530.45
# 31    28        Korea Republic          KOR       1529.30          1529.30
# 43    54          Saudi Arabia          KSA       1421.46          1421.46
# 45    59                 Qatar          QAT       1395.57          1393.52
# 44    70                  Iraq          IRQ       1345.21          1345.21
# 40    72  United Arab Emirates          UAE       1336.28          1336.28
# 36    73                  Oman          OMA       1332.45          1332.45
# 37    74            Uzbekistan          UZB       1327.58          1327.58
# 47    77               Lebanon          LIB       1308.00          1304.00
# ...

# %%
plt.figure(figsize=(22,6))

colors = ['yellow'] * 24
highlight_index = 18
colors[highlight_index] = 'red'  # Change the color of the highlighted bar

plt.bar(new_df_data['country_abrv'],new_df_data['rank'],color=colors)
plt.title("AFC Country Ranking (Lower Rank Indicates More Successful Team)", fontsize=18)
plt.annotate("India (Rank 99)",(17.2,110),color="r")
plt.xlabel("COUNTRIES",fontsize=15)
plt.ylabel("RANKS",fontsize=15)
plt.xticks(rotation=45)
plt.show()
#note here more the rank of the country is less the more successful team it is

# %%
plt.figure(figsize=(12, 6))

plt.plot(new_df_data['country_abrv'],new_df_data['rank'],linestyle='-',marker='o',color='b',markersize=8,markerfacecolor='r',label="Ranking Plotter")

plt.title("AFC Country Ranking", fontsize=15)
plt.xlabel("COUNTRIES", fontsize=15)
plt.ylabel("RANKS", fontsize=15)

plt.xticks(rotation=45, ha='right', fontsize=10)

plt.tight_layout()
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.boxplot(new_df_data['rank'])
plt.title("AFC Team's Ranking via BoxPlot")
plt.ylabel("Ranking")
plt.annotate("Japan will Qualify for World Cup 2026 Qualifiers",(1,20),xytext=(1.1,40),arrowprops=dict(arrowstyle="fancy"))
plt.show()

# %% [markdown]
# # ***Loading the dataset which will help us to see the performance of the team***

# %%
#now we will load the afc teams performance dataset
df2_data=pd.read_csv('/content/AFC_CUP_QUALIFICATION.csv')

df2_data
# Out:
#                     Team               Method of qualification  \
# 0                  Japan          Second round Group F winners
# 1                  Syria          Second round Group A winners
# 2                  Qatar  Hosts / Second round Group E winners
# 3            South Korea          Second round Group H winners
# 4              Australia          Second round Group B winners
# 5                   Iran          Second round Group C winners
# 6           Saudi Arabia          Second round Group D winners
# 7   United Arab Emirates          Second round Group G winners
# 8                  China       Second round Group A runners-up
# 9                   Iraq       Second round Group C runners-up
# 10                  Oman       Second round Group E runners-up
# 11               Vietnam       Second round Group G runners-up
# 12               Lebanon       Second round Group H runners-up
# 13             Palestine           Third round Group B winners
# ...

# %%
plt.figure(figsize=(15, 6))
plt.plot(df2_data['Team'], df2_data['Finals appearances'],'r--o')
plt.fill_between(df2_data['Team'], df2_data['Finals appearances'], color='red', alpha=0.5)
plt.xticks(rotation=90)
plt.title("Past AFC Teams Performance", fontsize=15)
plt.xlabel("Country", fontsize=15)
plt.ylabel("Appearances", fontsize=15)
plt.annotate("Max: 15 Appearances \n      South Korea",(3,15),xytext=(1.1,18),arrowprops=dict(arrowstyle="fancy"))
plt.annotate("Min: 1st Appearance \n        Tajikistan",(18,1),xytext=(18.1,10),arrowprops=dict(arrowstyle="fancy"))
plt.ylim(0,20)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.pie(df2_data['Finals appearances'],labels=df2_data['Team'],autopct="%1.2f%%",pctdistance=0.8)
plt.legend(loc='best', labels=df2_data['Team'])
plt.title("Winning Percentage",fontsize=20)
plt.axis('equal')
plt.show()

# %% [markdown]
# # ***ISL***

# %%
#now we will load the afc teams performance dataset
df3_data=pd.read_csv('/content/ISL.csv')

df3_data.head()
# Out:
#    tour_id tour_name    id  jersey_no                   name  \
# 0      148      ISL6  1514          3           Asamoah Gyan
# 1      148      ISL6  2475         26   Deshorn Dwayne Brown
# 2      148      ISL6  2900          9         Amine Chermiti
# 3      148      ISL6  3753          7  Francisco Medina Luna
# 4      148      ISL6  3809          4     Rafael Lopez Gomez
#
#            short_name  position_id    position position_short  team_id  ...  \
# 0        Asamoah Gyan            2     Forward            FWD      504  ...
# 1       Deshorn Brown            2     Forward            FWD      656  ...
# 2      Amine Chermiti            2     Forward            FWD      506  ...
# 3                Piti            3  Midfielder             MF     1159  ...
# 4  Rafael Lopez Gomez            1    Defender            DEF     1536  ...
#
#   goaltenders.catches goaltenders.punches  \
# 0                   0                   0
# 1                   0                   0
# ...

# %%
#dashboard of ISL League

plt.figure(figsize=(15,10))
plt.suptitle("Indian Super League Stats", fontsize=16)
custom_palette = sns.color_palette("Set1")

plt.subplot(2,2,1)
sns.barplot(x='team_short_name',y='events.goals',data=df3_data,palette=custom_palette)
plt.title("ISL Goals")

plt.subplot(2,2,2)
sns.lineplot(x='team_short_name',y='events.assists',data=df3_data,palette=custom_palette)
plt.title("ISL Assists")

plt.subplot(2,2,3)
sns.swarmplot(x='team_short_name',y='events.shots_on_target',data=df3_data,palette=custom_palette)
plt.title("ISL Shooting Accuracy")

plt.subplot(2,2,4)
sns.scatterplot(x='team_short_name',y='touches.total_passes',data=df3_data,palette=custom_palette)
plt.title("ISL Passes Count")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-72-57deb08198c6>:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='team_short_name',y='events.assists',data=df3_data,palette=custom_palette)
# <ipython-input-72-57deb08198c6>:16: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='team_short_name',y='events.shots_on_target',data=df3_data,palette=custom_palette)
# <ipython-input-72-57deb08198c6>:16: UserWarning:
# The palette list has fewer values (9) than needed (13) and will cycle, which may produce an uninterpretable plot.
#   sns.swarmplot(x='team_short_name',y='events.shots_on_target',data=df3_data,palette=custom_palette)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 42.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Define the name of the team you want to select players from
target_team = 'Mumbai City FC'

# Filter the DataFrame to select players from the target team
mcfc_players = df3_data[df3_data['team_name'] == target_team]

# Now, the 'mcfc_players' DataFrame contains only the players from the specified team
mcfc_players.head(10)
# Out:
#     tour_id tour_name     id  jersey_no  \
# 2       148      ISL6   2900          9
# 9       148      ISL6   3997          1
# 18      148      ISL6   7637         28
# 27      148      ISL6  10278         10
# 32      148      ISL6  10648          8
# 35      148      ISL6  10659         23
# 81      148      ISL6  19144         22
# 87      148      ISL6  19230         21
# 89      148      ISL6  21028         23
# 98      148      ISL6  25873         12
#
#                                       name          short_name  position_id  \
# 2                           Amine Chermiti      Amine Chermiti            2
# 9                    Amrinder Ranjit Singh      Amrinder Singh            4
# 18                      Pape Amodou Sougou        Modou Sougou            2
# 27  Paulo Ricardo Ribeiro De Jesus Machado       Paulo Machado            3
# 32                        Mohammed Rafique    Mohammed Rafique            3
# ...

# %%
#dashboard for checking the Attacking Of the Team
# Create a color palette for the plots
palette = "Set1"

# Create a figure with subplots
plt.figure(figsize=(12, 8))

# Dashboard Title
plt.suptitle("MCFC Attacking Performance of 8th Season", fontsize=16)

# Subplot 1: Goals Scored
plt.subplot(2, 2, 1)
sns.stripplot(x='position_short', y='events.goals', data=mcfc_players, palette=palette)
plt.title("Goals Scored")
plt.xlabel("Position")
plt.ylabel("Goals")

# Subplot 2: Assists
plt.subplot(2, 2, 2)
sns.boxplot(x='position_short', y='events.assists', data=mcfc_players, palette=palette)
plt.title("Assists")
plt.xlabel("Position")
plt.ylabel("Assists")

# Subplot 3: Shots on Target
plt.subplot(2, 2, 3)
sns.swarmplot(x='position_short', y='events.shots_on_target', data=mcfc_players, palette=palette)
plt.title("Shots on Target")
plt.xlabel("Position")
plt.ylabel("Shots on Target")

# Subplot 4: Possession
plt.subplot(2, 2, 4)
sns.barplot(x='position_short', y='touches.total_passes', data=mcfc_players, palette=palette)
plt.title("Possession")
plt.xlabel("Position")
plt.ylabel("Total Passes")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-88-c880f66bbe75>:13: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='position_short', y='events.goals', data=mcfc_players, palette=palette)
# <ipython-input-88-c880f66bbe75>:27: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='position_short', y='events.shots_on_target', data=mcfc_players, palette=palette)

# %%
palette = sns.color_palette("Set1")

plt.figure(figsize=(12, 8))

plt.suptitle("MCFC Defensive Performance of 8th Season", fontsize=16)

# Subplot 1: Interceptions
plt.subplot(2, 2, 1)
sns.stripplot(x='position_short', y='touches.interceptions', data=mcfc_players, palette=palette)
plt.title("Interceptions")
plt.xlabel("Position")
plt.ylabel("Interceptions")

# Subplot 2: Clearances
plt.subplot(2, 2, 2)
sns.boxplot(x='position_short', y='touches.clearance', data=mcfc_players, palette=palette)
plt.title("Clearances")
plt.xlabel("Position")
plt.ylabel("Clearances")
plt.annotate("Defensive Power", (2.5, 90), xytext=(1, 110), fontsize=10, color='blue',arrowprops=dict(arrowstyle="->", lw=1.5, color='blue'))

# Subplot 3: Tackles
plt.subplot(2, 2, 3)
sns.swarmplot(x='position_short', y='touches.tackles', data=mcfc_players, palette=palette)
plt.title("Tackles")
plt.xlabel("Position")
plt.ylabel("Tackles")

# Subplot 4: Fouls Committed
plt.subplot(2, 2, 4)
sns.barplot(x='position_short', y='events.fouls_committed', data=mcfc_players, palette=palette)
plt.title("Fouls Committed")
plt.xlabel("Position")
plt.ylabel("Fouls Committed")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-89-4fc979bb5e94>:9: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='position_short', y='touches.interceptions', data=mcfc_players, palette=palette)
# <ipython-input-89-4fc979bb5e94>:9: UserWarning: The palette list has more values (9) than needed (4), which may not be intended.
#   sns.stripplot(x='position_short', y='touches.interceptions', data=mcfc_players, palette=palette)
# <ipython-input-89-4fc979bb5e94>:24: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='position_short', y='touches.tackles', data=mcfc_players, palette=palette)
# <ipython-input-89-4fc979bb5e94>:24: UserWarning: The palette list has more values (9) than needed (4), which may not be intended.
#   sns.swarmplot(x='position_short', y='touches.tackles', data=mcfc_players, palette=palette)

# %% [markdown]
# # ***TOP GOAL SCORRER DATASET***

# %%
# Load the AFC teams performance dataset with ISO-8859-1 encoding
df4_data = pd.read_csv('/content/finaltryfortop.csv', encoding='ISO-8859-1')

df4_data.head()
# Out:
#    Rank             Player    Country  Goals  Caps  Ratio  First cap  \
# 0     1  Cristiano Ronaldo   Portugal    123   201   0.62  20-Aug-03
# 1     2           Ali Daei       Iran    108   148   0.73   6-Jun-93
# 2     3       Lionel Messi  Argentina    104   176   0.59  17-Aug-05
# 3     4      Sunil Chhetri      India     92   142   0.65  12-Jun-05
# 4     5     Mokhtar Dahari   Malaysia     89   142   0.63   5-Jun-72
#
#     Last cap
# 0   8-Sep-23
# 1  21-Jun-06
# 2   7-Sep-23
# 3   4-Jul-23
# 4  19-May-85

# %%
plt.figure(figsize=(17, 6))
sns.countplot(x=df4_data['Goals'],palette='rocket_r')
plt.title("International Goal Scores Count Plot")
plt.xlabel("Number of Gaols Scored")
plt.ylabel("Count")
plt.show()

# %%
bardata=df4_data.head(10)
bardata
# Out:
#    Rank              Player               Country  Goals  Caps  Ratio  \
# 0     1   Cristiano Ronaldo              Portugal    123   201   0.62
# 1     2            Ali Daei                  Iran    108   148   0.73
# 2     3        Lionel Messi             Argentina    104   176   0.59
# 3     4       Sunil Chhetri                 India     92   142   0.65
# 4     5      Mokhtar Dahari              Malaysia     89   142   0.63
# 5     6       Ferenc Puskás               Hungary     84    85   0.99
# 6     7        Ali Mabkhout  United Arab Emirates     81   109   0.74
# 7     8  Robert Lewandowski                Poland     81   144   0.56
# 8     9     Godfrey Chitalu                Zambia     79   111   0.71
# 9    10              Neymar                Brazil     79   126   0.63
#
#    First cap   Last cap
# 0  20-Aug-03   8-Sep-23
# 1   6-Jun-93  21-Jun-06
# 2  17-Aug-05   7-Sep-23
# 3  12-Jun-05   4-Jul-23
# 4   5-Jun-72  19-May-85
# 5  20-Aug-45  14-Oct-56
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

colors = ['lightgreen','lightgreen','lightgreen','lightcoral','lightgreen','lightgreen','lightgreen','lightgreen','lightgreen','lightgreen']
# Plot the bars with colors

bars = plt.bar(bardata['Player'], bardata['Goals'], color=colors)
plt.title("World Top Scorer")
plt.xlabel("Players")
plt.ylabel("Goals Scored")
plt.xticks(rotation=45)

# Load the image of the India flag
india_image = plt.imread('/content/Chhetri_(cropped).png')

# Define the position to place the image (for Sunil Chhetri)
x_position = bardata[bardata['Player'] == 'Sunil Chhetri'].index[0]
y_position = bardata['Goals'][x_position]

# Create an OffsetImage
india_flag = OffsetImage(india_image, zoom=0.05)

# Create an AnnotationBbox for the image
ab = AnnotationBbox(india_flag, (x_position, y_position), frameon=False)
ax.add_artist(ab)

plt.tight_layout()
plt.show()

# %% [markdown]
# # ***SAFF***

# %%
#now we will load the afc teams performance dataset
df5_data=pd.read_csv('/content/SAFF CHAMPIONSHIP CM.csv')

df5_data
# Out:
#       Country Appearance                          Previous best performance  \
# 0  Bangladesh       13th                                   Champions (2003)
# 1      Bhutan        9th                                 Semi-finals (2008)
# 2       India       14th  Champions (1993,1997,1999,2005,2009,2011,2015,...
# 3      Kuwait        1st                                    Debut (invitee)
# 4     Lebanon        1st                                    Debut (invitee)
# 5    Maldives       12th                              Champions (2008,2018)
# 6       Nepal       14th                                  Runners-up (2021)
# 7    Pakistan       12th                                 Third place (1997)
#
#    FIFA ranking (6 April 2023)  Title's Won
# 0                          192            1
# 1                          185            0
# 2                          101            8
# 3                          143            0
# 4                           99            0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Country", y="Title's Won", data=df5_data, hue='Country')
plt.xticks(rotation=45)
plt.title("Titles Won by Country")
plt.xlabel("Country")
plt.ylabel("Number of Titles")
plt.show()
